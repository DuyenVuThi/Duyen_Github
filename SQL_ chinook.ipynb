# %% [markdown]
# ### Introduction
# Here we examine the Chinook.db from the digital record store with tables for artists, albums, media tracks, invoices and customers. There are 11 tables with over 15,000 lines of data.
#
# We will complete a business analysis to see what insights we can uncover utilizing SQL queries.
#
# ![chinook-schema](https://s3.amazonaws.com/dq-content/191/chinook-schema.svg)

# %%
# !conda install -yc conda-forge ipython-sql
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook-unmodified.db

# %%
# %%sql
# SELECT
#     name,
#     type
# FROM sqlite_master
# WHERE type IN ("table","view");
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table'),
#  ('invoice_album_track', 'view'),
#  ('number_tracks_per_invoice', 'view'),
#  ('number_tracks_per_album', 'view'),
#  ('album_price', 'view')]

# %% [markdown]
# ### Selecting New Albums to Purchase
# The Chinook record store has just signed a deal with a new record label.
#
# #### Task: select the first three albums that will be added to the store
#
# From a list of four with genre
# * Red Tone (Punk)
# * Slim Jim Bites (Blues)
# * Meteor and the Girls (Pop)
# * Slim Jim Bite (Blues)
#
# The record label specializes in artists from the USA, and they have given Chinook some money to advertise the new albums in the USA, so we're interested in finding out which genres sell the best in the USA.

# %% [markdown]
# Note: calculate sum from total and group by genre is not correct since one total can have many genre, make the sum is double many time. As SUM(cc.quantity) is int, must change to float then it can devide

# %%
# %%sql
#
# WITH customer_country AS
#     (
#     SELECT
#         il.track_id,
#         il.quantity,
#         i.total,
#         c.country
#     FROM invoice_line il
#     INNER JOIN invoice i ON il.invoice_id=i.invoice_id
#     INNER JOIN customer c ON c.customer_id=i.customer_id
#     WHERE c.country="USA"
#     )
#
# SELECT
#     cc.country,
#     g.name genre,
#     SUM(cc.quantity) pruchased_quantity,
#     CAST(SUM(cc.quantity)AS FLOAT)/(SELECT COUNT(*) from customer_country)*100  percentage
# FROM track tr
# INNER JOIN customer_country cc ON cc.track_id=tr.track_id
# INNER JOIN genre g ON g.genre_id=tr.genre_id
# GROUP BY 2
# ORDER BY 3 DESC;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [('USA', 'Rock', 561, 53.37773549000951),
#  ('USA', 'Alternative & Punk', 130, 12.369172216936251),
#  ('USA', 'Metal', 124, 11.798287345385347),
#  ('USA', 'R&B/Soul', 53, 5.042816365366318),
#  ('USA', 'Blues', 36, 3.425309229305423),
#  ('USA', 'Alternative', 35, 3.3301617507136063),
#  ('USA', 'Pop', 22, 2.093244529019981),
#  ('USA', 'Latin', 22, 2.093244529019981),
#  ('USA', 'Hip Hop/Rap', 20, 1.9029495718363463),
#  ('USA', 'Jazz', 14, 1.3320647002854424),
#  ('USA', 'Easy Listening', 13, 1.236917221693625),
#  ('USA', 'Reggae', 6, 0.570884871550904),
#  ('USA', 'Electronica/Dance', 5, 0.47573739295908657),
#  ('USA', 'Classical', 4, 0.3805899143672693),
#  ('USA', 'Heavy Metal', 3, 0.285442435775452),
#  ('USA', 'Soundtrack', 2, 0.19029495718363465),
#  ('USA', 'TV Shows', 1, 0.09514747859181732)]

# %% [markdown]
# Based on the sales of tracks across different genres in the USA, we should purchase the new albums by the following artists:
#
# * Red Tone (Punk)
# * Slim Jim Bites (Blues)
# * Meteor and the Girls (Pop)
#
# It's worth keeping in mind that combined, these three genres only make up only 17% of total sales, so we should be on the lookout for artists and albums from the 'rock' genre, which accounts for 53% of sales.

# %% [markdown]
# ### Analyzing Employee Sales Performance
# Each customer for the Chinook store gets assigned to a sales support agent within the company when they first make a purchase.
# #### Task: analyze the purchases of customers belonging to each employee to see if any sales support agent is performing either better or worse than the others.

# %%
# %%sql
# WITH employee_value AS
#     (
#     SELECT
#         e.first_name||" "||e.last_name employee_name,
#         e.hire_date,
#         c.customer_id,
#         i.total
#     FROM employee e
#     LEFT JOIN customer c ON e.employee_id=c.support_rep_id
#     LEFT JOIN invoice i ON i.customer_id=c.customer_id
#     )
#
# SELECT
#     employee_name,
#     hire_date,
#     COUNT(DISTINCT customer_id) number_customer_care,
#     ROUND(SUM(total),2) total_revenuge,
#     ROUND(SUM(total)/COUNT(DISTINCT customer_id),2) avg_revenue_per_customer
# FROM employee_value
# GROUP BY 1
# ORDER BY 3 DESC;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [('Jane Peacock', '2017-04-01 00:00:00', 21, 1731.51, 82.45),
#  ('Margaret Park', '2017-05-03 00:00:00', 20, 1584.0, 79.2),
#  ('Steve Johnson', '2017-10-17 00:00:00', 18, 1393.92, 77.44),
#  ('Robert King', '2017-01-02 00:00:00', 0, None, None),
#  ('Nancy Edwards', '2016-05-01 00:00:00', 0, None, None),
#  ('Michael Mitchell', '2016-10-17 00:00:00', 0, None, None),
#  ('Laura Callahan', '2017-03-04 00:00:00', 0, None, None),
#  ('Andrew Adams', '2016-08-14 00:00:00', 0, None, None)]

# %% [markdown]
# Looking at table, only Jane, Margaret and Steve take care customers. While there is a 20% difference in sales between Jane (the top employee) and Steve (the bottom employee), the difference roughly corresponds with the differences in their hiring dates.

# %% [markdown]
# ### Analyzing Sales by Country
# For each country, include:
# * total number of customers
# * total value of sales
# * average value of sales per customer
# * average order value

# %%
# %%sql
#
# WITH country_revenue AS
#     (
#     SELECT
#         c.country,
#         c.customer_id,
#         i.total
#     FROM customer c
#     INNER JOIN invoice i ON i.customer_id=c.customer_id
#     )
#
# SELECT
#     country,
#     COUNT(DISTINCT customer_id) as total_customers,
#     ROUND(SUM(total),2) as total_sales,
#     ROUND(SUM(total)/COUNT(DISTINCT customer_id),2) as avg_sale_per_customer,
#     ROUND(AVG(total),2) as avg_order_value
# FROM country_revenue
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [('USA', 13, 1040.49, 80.04, 7.94),
#  ('Canada', 8, 535.59, 66.95, 7.05),
#  ('France', 5, 389.07, 77.81, 7.78),
#  ('Brazil', 5, 427.68, 85.54, 7.01),
#  ('Germany', 4, 334.62, 83.66, 8.16),
#  ('United Kingdom', 3, 245.52, 81.84, 8.77),
#  ('Portugal', 2, 185.13, 92.57, 6.38),
#  ('India', 2, 183.15, 91.58, 8.72),
#  ('Czech Republic', 2, 273.24, 136.62, 9.11),
#  ('Sweden', 1, 75.24, 75.24, 7.52),
#  ('Spain', 1, 98.01, 98.01, 8.91),
#  ('Poland', 1, 76.23, 76.23, 7.62),
#  ('Norway', 1, 72.27, 72.27, 8.03),
#  ('Netherlands', 1, 65.34, 65.34, 6.53),
#  ('Italy', 1, 50.49, 50.49, 5.61),
#  ('Ireland', 1, 114.84, 114.84, 8.83),
#  ('Hungary', 1, 78.21, 78.21, 7.82),
#  ('Finland', 1, 79.2, 79.2, 7.2),
#  ('Denmark', 1, 37.62, 37.62, 3.76),
#  ('Chile', 1, 97.02, 97.02, 7.46),
#  ('Belgium', 1, 60.39, 60.39, 8.63),
#  ('Austria', 1, 69.3, 69.3, 7.7),
#  ('Australia', 1, 81.18, 81.18, 8.12),
#  ('Argentina', 1, 39.6, 39.6, 7.92)]

# %% [markdown]
# Because there are a number of countries with only one customer, you should group these customers as "Other" in your analysis. You can use the following 'trick' to force the ordering of "Other" to last in your analysis.Based on the data, there may be opportunity in the following countries:
#
# * Czech Republic
# * United Kingdom
# * India
# It's worth keeping in mind that because the amount of data from each of these countries is relatively low. Because of this, we should be cautious spending too much money on new marketing campaigns, as the sample size is not large enough to give us high confidence. A better approach would be to run small campaigns in these countries, collecting and analyzing the new customers to make sure that these trends hold with new customers.

# %% [markdown]
# ### Albums vs Individual Tracks
# The Chinook store is setup in a way that allows customer to make purchases in one of the two ways:
# * purchase a whole album
# * purchase a collection of one or more individual tracks.
#
# The strategy: the management is considering to purchase only the most popular tracks from each album from record companies, instead of purchasing every track from an album.
#
# #### Task: find out what percentage of purchases are individual tracks vs whole albums
#
# So that management can use this data to understand the effect this decision might have on overall revenue.

# %% [markdown]
# ##### Some cases need to be considered:
# * Albums that have only one or two tracks are likely to be purchased by customers as part of a collection of individual tracks.
# * Customers may decide to manually select every track from an album, and then add a few individual tracks from other albums to their purchase.

# %%
# %%sql
# DROP VIEW IF EXISTS number_tracks_per_invoice;
# DROP VIEW IF EXISTS number_tracks_per_album;
# DROP VIEW IF EXISTS invoice_album_track;
# CREATE VIEW number_tracks_per_invoice AS
#     SELECT
#         il.invoice_id,
#         al.album_id as album_id,
#         COUNT(tr.track_id) as number_tracks
#     FROM invoice_line il
#     INNER JOIN track tr ON il.track_id=tr.track_id
#     INNER JOIN album al ON al.album_id=tr.album_id
#     GROUP BY 1,2;
#
# CREATE VIEW number_tracks_per_album AS
#     SELECT
#         al.album_id,
#         COUNT(tr.track_id) as number_tracks_per_album
#     FROM album al
#     INNER JOIN track tr ON tr.album_id=al.album_id
#     GROUP BY 1;
#
# CREATE VIEW invoice_album_track AS
# SELECT
#     pv.invoice_id,
#     pv.album_id,
#     pv.number_tracks,
#     pa.number_tracks_per_album,
#     CASE
#         WHEN pv.number_tracks= pa.number_tracks_per_album then "album"
#         ELSE "individual_track"
#         END AS album_individualtrack
# FROM number_tracks_per_invoice as pv
# LEFT JOIN number_tracks_per_album as pa ON pv.album_id=pa.album_id;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# From above table found that client can select some tracks from several album, some invoices have both individual track and album.So in order to have separate value of album & individual track, we caculate revenue of album first.

# %%
# %%sql
# select *
# from invoice_album_track
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [(1, 91, 16, 16, 'album'),
#  (2, 20, 1, 11, 'individual_track'),
#  (2, 34, 1, 17, 'individual_track'),
#  (2, 39, 1, 21, 'individual_track'),
#  (2, 66, 1, 10, 'individual_track'),
#  (2, 73, 1, 30, 'individual_track'),
#  (2, 134, 1, 10, 'individual_track'),
#  (2, 190, 1, 16, 'individual_track'),
#  (2, 215, 1, 14, 'individual_track'),
#  (2, 218, 1, 15, 'individual_track'),
#  (2, 322, 1, 11, 'individual_track'),
#  (3, 203, 1, 17, 'individual_track'),
#  (3, 214, 1, 11, 'individual_track'),
#  (4, 58, 1, 9, 'individual_track'),
#  (4, 67, 1, 16, 'individual_track'),
#  (4, 146, 1, 18, 'individual_track'),
#  (4, 153, 1, 13, 'individual_track'),
#  (4, 203, 1, 17, 'individual_track'),
#  (4, 207, 1, 11, 'individual_track'),
#  (4, 260, 1, 1, 'album'),
#  (4, 314, 1, 2, 'individual_track'),
#  (5, 163, 17, 17, 'album'),
#  (6, 5, 1, 15, 'individual_track'),
#  (6, 83, 1, 24, 'individual_track'),
#  (7, 6, 1, 13, 'individual_track'),
#  (7, 55, 1, 20, 'individual_track'),
#  (7, 67, 1, 16, 'individual_track'),
#  (7, 87, 1, 3, 'individual_track'),
#  (7, 106, 1, 9, 'individual_track'),
#  (7, 163, 1, 17, 'individual_track'),
#  (7, 211, 1, 18, 'individual_track'),
#  (7, 214, 1, 11, 'individual_track'),
#  (7, 239, 1, 10, 'individual_track'),
#  (7, 305, 1, 1, 'album'),
#  (7, 322, 1, 11, 'individual_track'),
#  (8, 9, 1, 8, 'individual_track'),
#  (8, 46, 1, 13, 'individual_track'),
#  (8, 118, 1, 11, 'individual_track'),
#  (8, 125, 1, 16, 'individual_track'),
#  (8, 144, 1, 10, 'individual_track'),
#  (8, 145, 1, 18, 'individual_track'),
#  (8, 183, 1, 9, 'individual_track'),
#  (8, 185, 1, 17, 'individual_track'),
#  (8, 203, 1, 17, 'individual_track'),
#  (8, 233, 1, 11, 'individual_track'),
#  (9, 20, 1, 11, 'individual_track'),
#  (9, 21, 1, 18, 'individual_track'),
#  (9, 79, 1, 10, 'individual_track'),
#  (9, 83, 1, 24, 'individual_track'),
#  (9, 101, 1, 10, 'individual_track'),
#  (9, 162, 1, 17, 'individual_track'),
#  (9, 173, 1, 2, 'individual_track'),
#  (9, 271, 1, 14, 'individual_track'),
#  (9, 321, 1, 12, 'individual_track'),
#  (10, 215, 1, 14, 'individual_track'),
#  (10, 257, 1, 12, 'individual_track'),
#  (11, 49, 1, 10, 'individual_track'),
#  (11, 89, 1, 13, 'individual_track'),
#  (11, 115, 1, 20, 'individual_track'),
#  (11, 181, 1, 11, 'individual_track'),
#  (11, 185, 1, 17, 'individual_track'),
#  (11, 195, 1, 15, 'individual_track'),
#  (11, 197, 1, 8, 'individual_track'),
#  (11, 211, 1, 18, 'individual_track'),
#  (11, 214, 1, 11, 'individual_track'),
#  (11, 243, 1, 17, 'individual_track'),
#  (11, 318, 1, 1, 'album'),
#  (12, 10, 1, 14, 'individual_track'),
#  (12, 54, 1, 20, 'individual_track'),
#  (12, 118, 1, 11, 'individual_track'),
#  (12, 215, 1, 14, 'individual_track'),
#  (13, 206, 1, 12, 'individual_track'),
#  (14, 42, 1, 14, 'individual_track'),
#  (15, 65, 1, 9, 'individual_track'),
#  (15, 120, 1, 17, 'individual_track'),
#  (15, 241, 1, 14, 'individual_track'),
#  (15, 260, 1, 1, 'album'),
#  (16, 4, 2, 8, 'individual_track'),
#  (16, 5, 1, 15, 'individual_track'),
#  (16, 9, 1, 8, 'individual_track'),
#  (16, 10, 1, 14, 'individual_track'),
#  (16, 70, 1, 13, 'individual_track'),
#  (16, 145, 1, 18, 'individual_track'),
#  (16, 178, 1, 16, 'individual_track'),
#  (16, 321, 1, 12, 'individual_track'),
#  (17, 7, 2, 12, 'individual_track'),
#  (17, 115, 1, 20, 'individual_track'),
#  (17, 131, 1, 8, 'individual_track'),
#  (17, 162, 1, 17, 'individual_track'),
#  (17, 179, 1, 13, 'individual_track'),
#  (17, 185, 1, 17, 'individual_track'),
#  (17, 195, 1, 15, 'individual_track'),
#  (17, 203, 1, 17, 'individual_track'),
#  (17, 206, 1, 12, 'individual_track'),
#  (17, 207, 1, 11, 'individual_track'),
#  (18, 82, 1, 13, 'individual_track'),
#  (18, 127, 1, 10, 'individual_track'),
#  (18, 141, 1, 57, 'individual_track'),
#  (18, 144, 1, 10, 'individual_track'),
#  (18, 221, 1, 20, 'individual_track'),
#  (19, 11, 1, 12, 'individual_track'),
#  (19, 103, 1, 10, 'individual_track'),
#  (19, 146, 1, 18, 'individual_track'),
#  (19, 203, 1, 17, 'individual_track'),
#  (19, 214, 1, 11, 'individual_track'),
#  (19, 216, 1, 12, 'individual_track'),
#  (19, 321, 1, 12, 'individual_track'),
#  (20, 7, 1, 12, 'individual_track'),
#  (20, 11, 1, 12, 'individual_track'),
#  (20, 30, 1, 14, 'individual_track'),
#  (20, 72, 1, 18, 'individual_track'),
#  (20, 88, 1, 12, 'individual_track'),
#  (20, 252, 1, 1, 'album'),
#  (20, 257, 2, 12, 'individual_track'),
#  (20, 260, 1, 1, 'album'),
#  (20, 267, 1, 1, 'album'),
#  (21, 1, 1, 10, 'individual_track'),
#  (21, 116, 1, 10, 'individual_track'),
#  (21, 118, 1, 11, 'individual_track'),
#  (21, 119, 1, 13, 'individual_track'),
#  (21, 121, 1, 10, 'individual_track'),
#  (21, 141, 1, 57, 'individual_track'),
#  (21, 207, 2, 11, 'individual_track'),
#  (21, 235, 1, 11, 'individual_track'),
#  (22, 33, 1, 17, 'individual_track'),
#  (22, 80, 1, 10, 'individual_track'),
#  (23, 1, 10, 10, 'album'),
#  (24, 90, 12, 12, 'album'),
#  (25, 5, 1, 15, 'individual_track'),
#  (25, 6, 1, 13, 'individual_track'),
#  (25, 75, 1, 14, 'individual_track'),
#  (25, 91, 1, 16, 'individual_track'),
#  (25, 119, 1, 13, 'individual_track'),
#  (25, 147, 1, 10, 'individual_track'),
#  (25, 180, 1, 15, 'individual_track'),
#  (25, 241, 1, 14, 'individual_track'),
#  (26, 10, 1, 14, 'individual_track'),
#  (26, 216, 1, 12, 'individual_track'),
#  (27, 101, 1, 10, 'individual_track'),
#  (27, 117, 1, 11, 'individual_track'),
#  (27, 121, 1, 10, 'individual_track'),
#  (27, 183, 2, 9, 'individual_track'),
#  (27, 238, 1, 14, 'individual_track'),
#  (27, 246, 1, 13, 'individual_track'),
#  (27, 305, 1, 1, 'album'),
#  (28, 5, 1, 15, 'individual_track'),
#  (28, 74, 1, 12, 'individual_track'),
#  (28, 321, 1, 12, 'individual_track'),
#  (29, 39, 1, 21, 'individual_track'),
#  (29, 82, 1, 13, 'individual_track'),
#  (29, 132, 1, 9, 'individual_track'),
#  (29, 195, 1, 15, 'individual_track'),
#  (29, 200, 1, 11, 'individual_track'),
#  (29, 261, 1, 17, 'individual_track'),
#  (30, 5, 1, 15, 'individual_track'),
#  (30, 73, 1, 30, 'individual_track'),
#  (30, 79, 1, 10, 'individual_track'),
#  (30, 89, 1, 13, 'individual_track'),
#  (30, 164, 1, 12, 'individual_track'),
#  (30, 191, 1, 10, 'individual_track'),
#  (30, 195, 1, 15, 'individual_track'),
#  (30, 196, 1, 14, 'individual_track'),
#  (30, 246, 1, 13, 'individual_track'),
#  (30, 321, 2, 12, 'individual_track'),
#  (31, 221, 20, 20, 'album'),
#  (32, 6, 13, 13, 'album'),
#  (33, 206, 1, 12, 'individual_track'),
#  (33, 218, 1, 15, 'individual_track'),
#  (33, 221, 1, 20, 'individual_track'),
#  (33, 258, 1, 19, 'individual_track'),
#  (34, 49, 1, 10, 'individual_track'),
#  (35, 1, 1, 10, 'individual_track'),
#  (35, 9, 1, 8, 'individual_track'),
#  (35, 67, 1, 16, 'individual_track'),
#  (35, 194, 1, 16, 'individual_track'),
#  (35, 322, 1, 11, 'individual_track'),
#  (36, 16, 1, 7, 'individual_track'),
#  (36, 77, 1, 11, 'individual_track'),
#  (36, 91, 1, 16, 'individual_track'),
#  (36, 120, 1, 17, 'individual_track'),
#  (36, 127, 1, 10, 'individual_track'),
#  (36, 183, 1, 9, 'individual_track'),
#  (36, 215, 1, 14, 'individual_track'),
#  (37, 55, 1, 20, 'individual_track'),
#  (37, 81, 1, 11, 'individual_track'),
#  (37, 91, 1, 16, 'individual_track'),
#  (37, 115, 1, 20, 'individual_track'),
#  (37, 145, 1, 18, 'individual_track'),
#  (37, 257, 1, 12, 'individual_track'),
#  (37, 259, 1, 17, 'individual_track'),
#  (37, 260, 1, 1, 'album'),
#  (37, 271, 1, 14, 'individual_track'),
#  (37, 321, 1, 12, 'individual_track'),
#  (38, 16, 1, 7, 'individual_track'),
#  (38, 119, 1, 13, 'individual_track'),
#  (38, 126, 1, 15, 'individual_track'),
#  (38, 207, 1, 11, 'individual_track'),
#  (38, 234, 1, 15, 'individual_track'),
#  (38, 255, 1, 23, 'individual_track'),
#  (38, 278, 1, 1, 'album'),
#  (39, 19, 1, 11, 'individual_track'),
#  (39, 138, 1, 4, 'individual_track'),
#  (39, 141, 1, 57, 'individual_track'),
#  (39, 189, 1, 14, 'individual_track'),
#  (39, 196, 1, 14, 'individual_track'),
#  (39, 203, 1, 17, 'individual_track'),
#  (39, 269, 1, 10, 'individual_track'),
#  (39, 293, 1, 1, 'album'),
#  (40, 11, 1, 12, 'individual_track'),
#  (40, 44, 1, 6, 'individual_track'),
#  (40, 54, 1, 20, 'individual_track'),
#  (40, 132, 1, 9, 'individual_track'),
#  (40, 183, 1, 9, 'individual_track'),
#  (40, 194, 1, 16, 'individual_track'),
#  (40, 207, 1, 11, 'individual_track'),
#  (40, 215, 1, 14, 'individual_track'),
#  (40, 221, 1, 20, 'individual_track'),
#  (40, 321, 1, 12, 'individual_track'),
#  (41, 16, 1, 7, 'individual_track'),
#  (41, 61, 1, 11, 'individual_track'),
#  (41, 160, 1, 15, 'individual_track'),
#  (41, 203, 1, 17, 'individual_track'),
#  (41, 218, 1, 15, 'individual_track'),
#  (41, 233, 1, 11, 'individual_track'),
#  (41, 260, 1, 1, 'album'),
#  (41, 321, 1, 12, 'individual_track'),
#  (42, 1, 1, 10, 'individual_track'),
#  (42, 16, 1, 7, 'individual_track'),
#  (42, 46, 1, 13, 'individual_track'),
#  (42, 55, 2, 20, 'individual_track'),
#  (42, 72, 1, 18, 'individual_track'),
#  (42, 83, 1, 24, 'individual_track'),
#  (42, 214, 1, 11, 'individual_track'),
#  (42, 243, 1, 17, 'individual_track'),
#  (43, 73, 1, 30, 'individual_track'),
#  (43, 91, 1, 16, 'individual_track'),
#  (43, 135, 1, 9, 'individual_track'),
#  (43, 145, 1, 18, 'individual_track'),
#  (43, 163, 1, 17, 'individual_track'),
#  (43, 191, 1, 10, 'individual_track'),
#  (43, 214, 1, 11, 'individual_track'),
#  (44, 242, 12, 12, 'album'),
#  (45, 11, 1, 12, 'individual_track'),
#  (45, 17, 1, 10, 'individual_track'),
#  (45, 146, 1, 18, 'individual_track'),
#  (45, 150, 1, 10, 'individual_track'),
#  (45, 155, 1, 11, 'individual_track'),
#  (45, 162, 1, 17, 'individual_track'),
#  (45, 214, 1, 11, 'individual_track'),
#  (45, 221, 1, 20, 'individual_track'),
#  (46, 214, 11, 11, 'album'),
#  (47, 1, 1, 10, 'individual_track'),
#  (47, 37, 1, 20, 'individual_track'),
#  (47, 39, 1, 21, 'individual_track'),
#  (47, 171, 1, 2, 'individual_track'),
#  (47, 203, 1, 17, 'individual_track'),
#  (47, 271, 1, 14, 'individual_track'),
#  (48, 7, 1, 12, 'individual_track'),
#  (48, 36, 1, 17, 'individual_track'),
#  (48, 91, 1, 16, 'individual_track'),
#  (48, 182, 1, 12, 'individual_track'),
#  (49, 15, 2, 5, 'individual_track'),
#  (49, 91, 1, 16, 'individual_track'),
#  (49, 154, 1, 8, 'individual_track'),
#  (49, 207, 1, 11, 'individual_track'),
#  (50, 122, 1, 14, 'individual_track'),
#  (50, 147, 1, 10, 'individual_track'),
#  (50, 157, 1, 14, 'individual_track'),
#  (50, 178, 1, 16, 'individual_track'),
#  (50, 199, 1, 12, 'individual_track'),
#  (50, 270, 1, 14, 'individual_track'),
#  (50, 321, 1, 12, 'individual_track'),
#  (51, 5, 1, 15, 'individual_track'),
#  (51, 13, 1, 8, 'individual_track'),
#  (51, 39, 1, 21, 'individual_track'),
#  (51, 54, 1, 20, 'individual_track'),
#  (51, 92, 1, 14, 'individual_track'),
#  (51, 179, 1, 13, 'individual_track'),
#  (51, 185, 1, 17, 'individual_track'),
#  (51, 241, 1, 14, 'individual_track'),
#  (52, 216, 12, 12, 'album'),
#  (53, 21, 1, 18, 'individual_track'),
#  (53, 125, 1, 16, 'individual_track'),
#  (53, 151, 1, 14, 'individual_track'),
#  (54, 146, 18, 18, 'album'),
#  (55, 16, 1, 7, 'individual_track'),
#  (55, 30, 1, 14, 'individual_track'),
#  (55, 39, 1, 21, 'individual_track'),
#  (55, 43, 1, 7, 'individual_track'),
#  (55, 125, 1, 16, 'individual_track'),
#  (55, 164, 1, 12, 'individual_track'),
#  (55, 199, 1, 12, 'individual_track'),
#  (55, 206, 1, 12, 'individual_track'),
#  (55, 216, 2, 12, 'individual_track'),
#  (56, 185, 17, 17, 'album'),
#  (57, 233, 1, 11, 'individual_track'),
#  (58, 82, 1, 13, 'individual_track'),
#  (58, 144, 1, 10, 'individual_track'),
#  (58, 195, 1, 15, 'individual_track'),
#  (58, 213, 1, 18, 'individual_track'),
#  (58, 214, 1, 11, 'individual_track'),
#  (58, 216, 1, 12, 'individual_track'),
#  (59, 20, 1, 11, 'individual_track'),
#  (59, 37, 1, 20, 'individual_track'),
#  (59, 83, 1, 24, 'individual_track'),
#  (59, 88, 1, 12, 'individual_track'),
#  (59, 118, 1, 11, 'individual_track'),
#  (59, 207, 1, 11, 'individual_track'),
#  (59, 214, 1, 11, 'individual_track'),
#  (59, 221, 1, 20, 'individual_track'),
#  (59, 260, 1, 1, 'album'),
#  (59, 271, 1, 14, 'individual_track'),
#  (59, 336, 1, 1, 'album'),
#  (60, 6, 1, 13, 'individual_track'),
#  (60, 39, 1, 21, 'individual_track'),
#  (60, 43, 1, 7, 'individual_track'),
#  (60, 82, 1, 13, 'individual_track'),
#  (60, 91, 1, 16, 'individual_track'),
#  (60, 149, 1, 16, 'individual_track'),
#  (60, 154, 1, 8, 'individual_track'),
#  (60, 196, 1, 14, 'individual_track'),
#  (61, 212, 12, 12, 'album'),
#  (62, 10, 1, 14, 'individual_track'),
#  (62, 217, 1, 14, 'individual_track'),
#  (62, 237, 1, 17, 'individual_track'),
#  (63, 1, 2, 10, 'individual_track'),
#  (63, 37, 1, 20, 'individual_track'),
#  (63, 163, 1, 17, 'individual_track'),
#  (63, 270, 1, 14, 'individual_track'),
#  (63, 322, 1, 11, 'individual_track'),
#  (64, 6, 13, 13, 'album'),
#  (65, 42, 1, 14, 'individual_track'),
#  (65, 89, 1, 13, 'individual_track'),
#  (66, 37, 1, 20, 'individual_track'),
#  (66, 116, 1, 10, 'individual_track'),
#  (66, 145, 1, 18, 'individual_track'),
#  (66, 146, 1, 18, 'individual_track'),
#  (66, 160, 1, 15, 'individual_track'),
#  (66, 191, 1, 10, 'individual_track'),
#  (66, 270, 1, 14, 'individual_track'),
#  (67, 1, 1, 10, 'individual_track'),
#  (67, 9, 1, 8, 'individual_track'),
#  (67, 63, 1, 12, 'individual_track'),
#  (67, 69, 1, 13, 'individual_track'),
#  (67, 178, 1, 16, 'individual_track'),
#  (67, 188, 1, 11, 'individual_track'),
#  (67, 195, 1, 15, 'individual_track'),
#  (67, 196, 1, 14, 'individual_track'),
#  (67, 245, 1, 12, 'individual_track'),
#  (67, 322, 1, 11, 'individual_track'),
#  (67, 323, 1, 1, 'album'),
#  (68, 7, 1, 12, 'individual_track'),
#  (68, 58, 1, 9, 'individual_track'),
#  (68, 73, 1, 30, 'individual_track'),
#  (68, 138, 1, 4, 'individual_track'),
#  (68, 157, 1, 14, 'individual_track'),
#  (68, 163, 1, 17, 'individual_track'),
#  (68, 164, 1, 12, 'individual_track'),
#  (68, 183, 1, 9, 'individual_track'),
#  (68, 185, 1, 17, 'individual_track'),
#  (68, 209, 1, 10, 'individual_track'),
#  (68, 265, 1, 2, 'individual_track'),
#  (69, 10, 14, 14, 'album'),
#  (70, 189, 1, 14, 'individual_track'),
#  (71, 185, 17, 17, 'album'),
#  (72, 5, 1, 15, 'individual_track'),
#  (72, 136, 1, 7, 'individual_track'),
#  (72, 207, 1, 11, 'individual_track'),
#  (73, 195, 15, 15, 'album'),
#  (74, 142, 1, 14, 'individual_track'),
#  (74, 244, 1, 11, 'individual_track'),
#  (75, 4, 1, 8, 'individual_track'),
#  (75, 96, 1, 11, 'individual_track'),
#  (75, 120, 1, 17, 'individual_track'),
#  (75, 162, 1, 17, 'individual_track'),
#  (76, 82, 13, 13, 'album'),
#  (77, 4, 6, 8, 'individual_track'),
#  (78, 5, 1, 15, 'individual_track'),
#  (78, 83, 1, 24, 'individual_track'),
#  (78, 88, 1, 12, 'individual_track'),
#  (78, 95, 1, 12, 'individual_track'),
#  (78, 206, 1, 12, 'individual_track'),
#  (78, 211, 1, 18, 'individual_track'),
#  (78, 238, 1, 14, 'individual_track'),
#  (78, 260, 1, 1, 'album'),
#  (78, 269, 1, 10, 'individual_track'),
#  (79, 157, 14, 14, 'album'),
#  (80, 271, 1, 14, 'individual_track'),
#  (81, 43, 1, 7, 'individual_track'),
#  (81, 67, 1, 16, 'individual_track'),
#  (81, 72, 1, 18, 'individual_track'),
#  (81, 103, 1, 10, 'individual_track'),
#  (81, 207, 1, 11, 'individual_track'),
#  (81, 243, 1, 17, 'individual_track'),
#  (82, 7, 1, 12, 'individual_track'),
#  (82, 105, 1, 10, 'individual_track'),
#  (82, 107, 1, 8, 'individual_track'),
#  (82, 175, 1, 12, 'individual_track'),
#  (82, 196, 1, 14, 'individual_track'),
#  (82, 218, 1, 15, 'individual_track'),
#  (82, 257, 1, 12, 'individual_track'),
#  (83, 91, 1, 16, 'individual_track'),
#  (83, 163, 1, 17, 'individual_track'),
#  (83, 221, 1, 20, 'individual_track'),
#  (83, 237, 1, 17, 'individual_track'),
#  (84, 321, 12, 12, 'album'),
#  (85, 102, 1, 18, 'individual_track'),
#  (85, 162, 1, 17, 'individual_track'),
#  (85, 207, 2, 11, 'individual_track'),
#  (85, 221, 1, 20, 'individual_track'),
#  (86, 188, 1, 11, 'individual_track'),
#  (87, 88, 1, 12, 'individual_track'),
#  (87, 121, 1, 10, 'individual_track'),
#  (87, 129, 1, 8, 'individual_track'),
#  (87, 141, 1, 57, 'individual_track'),
#  (87, 211, 1, 18, 'individual_track'),
#  (87, 257, 1, 12, 'individual_track'),
#  (87, 262, 1, 2, 'individual_track'),
#  (87, 305, 1, 1, 'album'),
#  (88, 163, 1, 17, 'individual_track'),
#  (88, 194, 1, 16, 'individual_track'),
#  (88, 211, 1, 18, 'individual_track'),
#  (88, 217, 1, 14, 'individual_track'),
#  (88, 218, 1, 15, 'individual_track'),
#  (89, 146, 1, 18, 'individual_track'),
#  (89, 156, 1, 9, 'individual_track'),
#  (90, 207, 11, 11, 'album'),
#  (91, 10, 1, 14, 'individual_track'),
#  (91, 13, 1, 8, 'individual_track'),
#  (91, 39, 1, 21, 'individual_track'),
#  (91, 94, 1, 11, 'individual_track'),
#  (91, 120, 1, 17, 'individual_track'),
#  (91, 149, 1, 16, 'individual_track'),
#  (91, 160, 1, 15, 'individual_track'),
#  (91, 193, 1, 17, 'individual_track'),
#  (91, 211, 1, 18, 'individual_track'),
#  (91, 215, 1, 14, 'individual_track'),
#  (91, 293, 1, 1, 'album'),
#  (92, 115, 20, 20, 'album'),
#  (93, 4, 1, 8, 'individual_track'),
#  (93, 61, 1, 11, 'individual_track'),
#  (93, 82, 1, 13, 'individual_track'),
#  (93, 88, 1, 12, 'individual_track'),
#  (93, 120, 1, 17, 'individual_track'),
#  (93, 146, 1, 18, 'individual_track'),
#  (93, 147, 1, 10, 'individual_track'),
#  (93, 185, 1, 17, 'individual_track'),
#  (93, 214, 1, 11, 'individual_track'),
#  (93, 241, 1, 14, 'individual_track'),
#  (94, 6, 1, 13, 'individual_track'),
#  (94, 84, 1, 16, 'individual_track'),
#  (94, 91, 1, 16, 'individual_track'),
#  (94, 107, 1, 8, 'individual_track'),
#  (94, 139, 1, 15, 'individual_track'),
#  (94, 211, 1, 18, 'individual_track'),
#  (94, 215, 1, 14, 'individual_track'),
#  (94, 268, 1, 1, 'album'),
#  (95, 5, 1, 15, 'individual_track'),
#  (95, 7, 1, 12, 'individual_track'),
#  (95, 11, 1, 12, 'individual_track'),
#  (95, 39, 1, 21, 'individual_track'),
#  (95, 54, 1, 20, 'individual_track'),
#  (95, 80, 1, 10, 'individual_track'),
#  (95, 101, 1, 10, 'individual_track'),
#  (95, 191, 1, 10, 'individual_track'),
#  (95, 206, 1, 12, 'individual_track'),
#  (95, 243, 1, 17, 'individual_track'),
#  (95, 257, 1, 12, 'individual_track'),
#  (96, 37, 1, 20, 'individual_track'),
#  (96, 80, 1, 10, 'individual_track'),
#  (96, 88, 1, 12, 'individual_track'),
#  (96, 141, 1, 57, 'individual_track'),
#  (96, 180, 1, 15, 'individual_track'),
#  (96, 280, 1, 2, 'individual_track'),
#  (97, 4, 1, 8, 'individual_track'),
#  (97, 37, 1, 20, 'individual_track'),
#  (97, 146, 1, 18, 'individual_track'),
#  (97, 206, 1, 12, 'individual_track'),
#  (97, 246, 1, 13, 'individual_track'),
#  (97, 260, 1, 1, 'album'),
#  (98, 36, 1, 17, 'individual_track'),
#  (98, 48, 1, 13, 'individual_track'),
#  (98, 54, 1, 20, 'individual_track'),
#  (98, 151, 1, 14, 'individual_track'),
#  (98, 157, 1, 14, 'individual_track'),
#  (98, 163, 1, 17, 'individual_track'),
#  (98, 185, 1, 17, 'individual_track'),
#  (98, 197, 1, 8, 'individual_track'),
#  (98, 213, 1, 18, 'individual_track'),
#  (98, 214, 1, 11, 'individual_track'),
#  (99, 211, 18, 18, 'album'),
#  (100, 79, 1, 10, 'individual_track'),
#  (100, 92, 1, 14, 'individual_track'),
#  (100, 120, 1, 17, 'individual_track'),
#  (100, 164, 1, 12, 'individual_track'),
#  (100, 207, 1, 11, 'individual_track'),
#  (100, 214, 1, 11, 'individual_track'),
#  (101, 9, 1, 8, 'individual_track'),
#  (101, 185, 1, 17, 'individual_track'),
#  (101, 203, 1, 17, 'individual_track'),
#  (101, 266, 1, 1, 'album'),
#  (102, 5, 1, 15, 'individual_track'),
#  (102, 36, 1, 17, 'individual_track'),
#  (102, 93, 1, 13, 'individual_track'),
#  (102, 95, 1, 12, 'individual_track'),
#  (102, 110, 1, 8, 'individual_track'),
#  (102, 119, 1, 13, 'individual_track'),
#  (102, 120, 1, 17, 'individual_track'),
#  (102, 163, 1, 17, 'individual_track'),
#  (102, 206, 1, 12, 'individual_track'),
#  (102, 322, 1, 11, 'individual_track'),
#  (103, 82, 1, 13, 'individual_track'),
#  (103, 164, 1, 12, 'individual_track'),
#  (103, 183, 1, 9, 'individual_track'),
#  (103, 186, 1, 11, 'individual_track'),
#  (103, 196, 1, 14, 'individual_track'),
#  (103, 260, 1, 1, 'album'),
#  (104, 122, 1, 14, 'individual_track'),
#  (104, 245, 1, 12, 'individual_track'),
#  (105, 58, 1, 9, 'individual_track'),
#  (105, 112, 1, 8, 'individual_track'),
#  (105, 147, 1, 10, 'individual_track'),
#  (105, 180, 1, 15, 'individual_track'),
#  (105, 194, 2, 16, 'individual_track'),
#  (105, 221, 1, 20, 'individual_track'),
#  (105, 265, 1, 2, 'individual_track'),
#  (106, 2, 1, 1, 'album'),
#  (106, 39, 1, 21, 'individual_track'),
#  (106, 120, 1, 17, 'individual_track'),
#  (106, 128, 1, 8, 'individual_track'),
#  (106, 141, 1, 57, 'individual_track'),
#  (106, 149, 1, 16, 'individual_track'),
#  (106, 180, 1, 15, 'individual_track'),
#  (106, 322, 1, 11, 'individual_track'),
#  (107, 1, 1, 10, 'individual_track'),
#  (107, 5, 1, 15, 'individual_track'),
#  (107, 55, 1, 20, 'individual_track'),
#  (107, 88, 1, 12, 'individual_track'),
#  (107, 92, 1, 14, 'individual_track'),
#  (107, 147, 1, 10, 'individual_track'),
#  (107, 149, 1, 16, 'individual_track'),
#  (107, 162, 1, 17, 'individual_track'),
#  (107, 164, 1, 12, 'individual_track'),
#  (107, 196, 1, 14, 'individual_track'),
#  (107, 257, 1, 12, 'individual_track'),
#  (108, 7, 1, 12, 'individual_track'),
#  (108, 11, 1, 12, 'individual_track'),
#  (108, 17, 1, 10, 'individual_track'),
#  (108, 95, 1, 12, 'individual_track'),
#  (108, 221, 1, 20, 'individual_track'),
#  (109, 30, 1, 14, 'individual_track'),
#  (109, 36, 1, 17, 'individual_track'),
#  (109, 39, 1, 21, 'individual_track'),
#  (109, 54, 1, 20, 'individual_track'),
#  (109, 55, 1, 20, 'individual_track'),
#  (109, 83, 1, 24, 'individual_track'),
#  (109, 93, 1, 13, 'individual_track'),
#  (109, 141, 1, 57, 'individual_track'),
#  (109, 147, 1, 10, 'individual_track'),
#  (109, 194, 1, 16, 'individual_track'),
#  (109, 257, 1, 12, 'individual_track'),
#  (110, 9, 1, 8, 'individual_track'),
#  (110, 37, 1, 20, 'individual_track'),
#  (110, 183, 1, 9, 'individual_track'),
#  (110, 211, 1, 18, 'individual_track'),
#  (110, 246, 1, 13, 'individual_track'),
#  (110, 270, 1, 14, 'individual_track'),
#  (111, 6, 1, 13, 'individual_track'),
#  (111, 48, 1, 13, 'individual_track'),
#  (111, 89, 1, 13, 'individual_track'),
#  (111, 198, 1, 6, 'individual_track'),
#  (111, 329, 1, 1, 'album'),
#  (112, 120, 17, 17, 'album'),
#  (113, 14, 1, 13, 'individual_track'),
#  (113, 46, 1, 13, 'individual_track'),
#  (113, 83, 1, 24, 'individual_track'),
#  (113, 119, 1, 13, 'individual_track'),
#  (113, 136, 1, 7, 'individual_track'),
#  (113, 194, 1, 16, 'individual_track'),
#  (113, 215, 1, 14, 'individual_track'),
#  (113, 218, 1, 15, 'individual_track'),
#  (113, 222, 1, 15, 'individual_track'),
#  (113, 244, 1, 11, 'individual_track'),
#  (114, 120, 17, 17, 'album'),
#  (115, 9, 1, 8, 'individual_track'),
#  (115, 26, 1, 17, 'individual_track'),
#  (115, 93, 1, 13, 'individual_track'),
#  (115, 96, 1, 11, 'individual_track'),
#  (115, 185, 1, 17, 'individual_track'),
#  (115, 212, 1, 12, 'individual_track'),
#  (115, 217, 1, 14, 'individual_track'),
#  (115, 237, 1, 17, 'individual_track'),
#  (115, 269, 1, 10, 'individual_track'),
#  (116, 4, 1, 8, 'individual_track'),
#  (116, 5, 1, 15, 'individual_track'),
#  (116, 8, 1, 14, 'individual_track'),
#  (116, 46, 1, 13, 'individual_track'),
#  (116, 92, 1, 14, 'individual_track'),
#  (116, 126, 1, 15, 'individual_track'),
#  (116, 155, 1, 11, 'individual_track'),
#  (116, 185, 1, 17, 'individual_track'),
#  (116, 221, 1, 20, 'individual_track'),
#  (116, 236, 1, 12, 'individual_track'),
#  (116, 245, 1, 12, 'individual_track'),
#  (117, 3, 1, 3, 'individual_track'),
#  (117, 49, 1, 10, 'individual_track'),
#  (117, 67, 1, 16, 'individual_track'),
#  (117, 120, 1, 17, 'individual_track'),
#  (117, 154, 1, 8, 'individual_track'),
#  (117, 179, 1, 13, 'individual_track'),
#  (117, 207, 1, 11, 'individual_track'),
#  (117, 211, 1, 18, 'individual_track'),
#  (117, 258, 2, 19, 'individual_track'),
#  (117, 269, 1, 10, 'individual_track'),
#  (118, 246, 1, 13, 'individual_track'),
#  (119, 125, 1, 16, 'individual_track'),
#  (119, 203, 1, 17, 'individual_track'),
#  (120, 4, 1, 8, 'individual_track'),
#  (120, 88, 1, 12, 'individual_track'),
#  (120, 192, 1, 14, 'individual_track'),
#  (120, 211, 1, 18, 'individual_track'),
#  (120, 221, 2, 20, 'individual_track'),
#  (121, 5, 1, 15, 'individual_track'),
#  (121, 6, 2, 13, 'individual_track'),
#  (121, 30, 1, 14, 'individual_track'),
#  (121, 150, 1, 10, 'individual_track'),
#  (121, 206, 1, 12, 'individual_track'),
#  (121, 215, 1, 14, 'individual_track'),
#  (121, 216, 1, 12, 'individual_track'),
#  (121, 318, 1, 1, 'album'),
#  (122, 5, 1, 15, 'individual_track'),
#  (122, 6, 1, 13, 'individual_track'),
#  (122, 67, 1, 16, 'individual_track'),
#  (122, 93, 1, 13, 'individual_track'),
#  (122, 164, 1, 12, 'individual_track'),
#  (123, 164, 12, 12, 'album'),
#  (124, 39, 1, 21, 'individual_track'),
#  (124, 81, 1, 11, 'individual_track'),
#  (124, 149, 1, 16, 'individual_track'),
#  (124, 190, 1, 16, 'individual_track'),
#  (124, 245, 1, 12, 'individual_track'),
#  (124, 259, 1, 17, 'individual_track'),
#  (125, 6, 1, 13, 'individual_track'),
#  (125, 16, 1, 7, 'individual_track'),
#  (125, 20, 1, 11, 'individual_track'),
#  (125, 23, 1, 34, 'individual_track'),
#  (125, 38, 1, 12, 'individual_track'),
#  (125, 149, 1, 16, 'individual_track'),
#  (125, 151, 1, 14, 'individual_track'),
#  (125, 194, 1, 16, 'individual_track'),
#  (125, 195, 1, 15, 'individual_track'),
#  (125, 264, 1, 2, 'individual_track'),
#  (126, 6, 1, 13, 'individual_track'),
#  (126, 178, 1, 16, 'individual_track'),
#  (126, 194, 1, 16, 'individual_track'),
#  (126, 203, 1, 17, 'individual_track'),
#  (127, 2, 1, 1, 'album'),
#  (127, 88, 1, 12, 'individual_track'),
#  (127, 120, 1, 17, 'individual_track'),
#  (127, 141, 1, 57, 'individual_track'),
#  (127, 150, 1, 10, 'individual_track'),
#  (127, 190, 1, 16, 'individual_track'),
#  (127, 207, 1, 11, 'individual_track'),
#  (127, 243, 1, 17, 'individual_track'),
#  (127, 269, 1, 10, 'individual_track'),
#  (127, 270, 1, 14, 'individual_track'),
#  (127, 321, 1, 12, 'individual_track'),
#  (128, 67, 1, 16, 'individual_track'),
#  (128, 192, 1, 14, 'individual_track'),
#  (128, 207, 1, 11, 'individual_track'),
#  (128, 217, 1, 14, 'individual_track'),
#  (128, 239, 2, 10, 'individual_track'),
#  (128, 256, 1, 12, 'individual_track'),
#  (129, 1, 1, 10, 'individual_track'),
#  (129, 10, 1, 14, 'individual_track'),
#  (129, 61, 1, 11, 'individual_track'),
#  (129, 67, 2, 16, 'individual_track'),
#  (129, 81, 1, 11, 'individual_track'),
#  (129, 127, 1, 10, 'individual_track'),
#  (129, 134, 1, 10, 'individual_track'),
#  (129, 154, 1, 8, 'individual_track'),
#  (129, 192, 1, 14, 'individual_track'),
#  (129, 207, 1, 11, 'individual_track'),
#  (130, 126, 1, 15, 'individual_track'),
#  (130, 178, 1, 16, 'individual_track'),
#  (130, 203, 1, 17, 'individual_track'),
#  (130, 215, 1, 14, 'individual_track'),
#  (131, 73, 1, 30, 'individual_track'),
#  (131, 136, 1, 7, 'individual_track'),
#  (131, 144, 1, 10, 'individual_track'),
#  (132, 183, 1, 9, 'individual_track'),
#  (132, 221, 1, 20, 'individual_track'),
#  (133, 5, 1, 15, 'individual_track'),
#  (133, 7, 1, 12, 'individual_track'),
#  (133, 35, 1, 11, 'individual_track'),
#  (133, 83, 1, 24, 'individual_track'),
#  (133, 120, 1, 17, 'individual_track'),
#  (133, 131, 1, 8, 'individual_track'),
#  (133, 146, 1, 18, 'individual_track'),
#  (133, 163, 1, 17, 'individual_track'),
#  (133, 217, 1, 14, 'individual_track'),
#  (133, 241, 1, 14, 'individual_track'),
#  (134, 20, 1, 11, 'individual_track'),
#  (134, 23, 1, 34, 'individual_track'),
#  (134, 37, 2, 20, 'individual_track'),
#  (134, 148, 1, 12, 'individual_track'),
#  (134, 178, 1, 16, 'individual_track'),
#  (134, 270, 1, 14, 'individual_track'),
#  (134, 339, 1, 1, 'album'),
#  (135, 95, 1, 12, 'individual_track'),
#  (135, 203, 1, 17, 'individual_track'),
#  (135, 234, 1, 15, 'individual_track'),
#  (136, 90, 1, 12, 'individual_track'),
#  (136, 91, 1, 16, 'individual_track'),
#  (136, 125, 1, 16, 'individual_track'),
#  (136, 184, 1, 16, 'individual_track'),
#  (137, 6, 1, 13, 'individual_track'),
#  (137, 260, 1, 1, 'album'),
#  (138, 186, 11, 11, 'album'),
#  (139, 62, 1, 7, 'individual_track'),
#  (139, 89, 1, 13, 'individual_track'),
#  (139, 149, 1, 16, 'individual_track'),
#  (139, 214, 1, 11, 'individual_track'),
#  (139, 221, 1, 20, 'individual_track'),
#  (140, 39, 1, 21, 'individual_track'),
#  (140, 55, 1, 20, 'individual_track'),
#  (140, 66, 1, 10, 'individual_track'),
#  (140, 80, 1, 10, 'individual_track'),
#  (140, 90, 1, 12, 'individual_track'),
#  (140, 108, 1, 10, 'individual_track'),
#  (140, 178, 1, 16, 'individual_track'),
#  (140, 206, 1, 12, 'individual_track'),
#  (141, 213, 18, 18, 'album'),
#  (142, 5, 15, 15, 'album'),
#  (143, 39, 1, 21, 'individual_track'),
#  (143, 48, 1, 13, 'individual_track'),
#  (143, 73, 1, 30, 'individual_track'),
#  (143, 74, 1, 12, 'individual_track'),
#  (143, 211, 1, 18, 'individual_track'),
#  (144, 17, 1, 10, 'individual_track'),
#  (144, 210, 1, 9, 'individual_track'),
#  (144, 257, 1, 12, 'individual_track'),
#  (145, 115, 1, 20, 'individual_track'),
#  (145, 194, 2, 16, 'individual_track'),
#  (145, 203, 1, 17, 'individual_track'),
#  (145, 255, 1, 23, 'individual_track'),
#  (146, 119, 13, 13, 'album'),
#  (147, 7, 1, 12, 'individual_track'),
#  (147, 120, 1, 17, 'individual_track'),
#  (147, 193, 1, 17, 'individual_track'),
#  (147, 206, 1, 12, 'individual_track'),
#  (147, 243, 1, 17, 'individual_track'),
#  (148, 5, 1, 15, 'individual_track'),
#  (148, 7, 1, 12, 'individual_track'),
#  (148, 89, 1, 13, 'individual_track'),
#  (148, 120, 1, 17, 'individual_track'),
#  (148, 134, 1, 10, 'individual_track'),
#  (148, 160, 1, 15, 'individual_track'),
#  (148, 163, 1, 17, 'individual_track'),
#  (148, 174, 1, 14, 'individual_track'),
#  (148, 321, 1, 12, 'individual_track'),
#  (149, 5, 1, 15, 'individual_track'),
#  (149, 17, 1, 10, 'individual_track'),
#  (149, 67, 1, 16, 'individual_track'),
#  (149, 82, 1, 13, 'individual_track'),
#  (149, 90, 1, 12, 'individual_track'),
#  (149, 91, 1, 16, 'individual_track'),
#  (149, 102, 1, 18, 'individual_track'),
#  (149, 162, 1, 17, 'individual_track'),
#  (149, 215, 1, 14, 'individual_track'),
#  (150, 82, 1, 13, 'individual_track'),
#  (150, 92, 1, 14, 'individual_track'),
#  (150, 271, 1, 14, 'individual_track'),
#  (151, 48, 1, 13, 'individual_track'),
#  (151, 147, 1, 10, 'individual_track'),
#  (151, 322, 1, 11, 'individual_track'),
#  (152, 82, 1, 13, 'individual_track'),
#  (152, 118, 1, 11, 'individual_track'),
#  (152, 155, 1, 11, 'individual_track'),
#  (152, 183, 1, 9, 'individual_track'),
#  (152, 207, 1, 11, 'individual_track'),
#  (152, 221, 1, 20, 'individual_track'),
#  (153, 196, 14, 14, 'album'),
#  (154, 214, 1, 11, 'individual_track'),
#  (154, 217, 1, 14, 'individual_track'),
#  (154, 258, 1, 19, 'individual_track'),
#  (155, 10, 1, 14, 'individual_track'),
#  (155, 37, 1, 20, 'individual_track'),
#  (155, 47, 1, 14, 'individual_track'),
#  (155, 88, 1, 12, 'individual_track'),
#  (155, 92, 1, 14, 'individual_track'),
#  (155, 125, 1, 16, 'individual_track'),
#  (155, 160, 1, 15, 'individual_track'),
#  (155, 190, 1, 16, 'individual_track'),
#  (155, 193, 1, 17, 'individual_track'),
#  (156, 155, 11, 11, 'album'),
#  (157, 260, 1, 1, 'album'),
#  (158, 83, 1, 24, 'individual_track'),
#  (158, 89, 1, 13, 'individual_track'),
#  (158, 92, 1, 14, 'individual_track'),
#  (158, 119, 1, 13, 'individual_track'),
#  (158, 237, 1, 17, 'individual_track'),
#  (158, 246, 1, 13, 'individual_track'),
#  (159, 16, 1, 7, 'individual_track'),
#  (159, 141, 1, 57, 'individual_track'),
#  (159, 194, 1, 16, 'individual_track'),
#  (159, 199, 1, 12, 'individual_track'),
#  (159, 206, 1, 12, 'individual_track'),
#  (159, 242, 1, 12, 'individual_track'),
#  (160, 5, 1, 15, 'individual_track'),
#  (160, 39, 1, 21, 'individual_track'),
#  (160, 80, 1, 10, 'individual_track'),
#  (160, 83, 1, 24, 'individual_track'),
#  (160, 104, 1, 10, 'individual_track'),
#  (160, 154, 1, 8, 'individual_track'),
#  (160, 196, 1, 14, 'individual_track'),
#  (160, 321, 1, 12, 'individual_track'),
#  (160, 322, 1, 11, 'individual_track'),
#  (161, 7, 1, 12, 'individual_track'),
#  (161, 115, 1, 20, 'individual_track'),
#  (161, 126, 1, 15, 'individual_track'),
#  (161, 149, 1, 16, 'individual_track'),
#  (161, 174, 1, 14, 'individual_track'),
#  (161, 210, 1, 9, 'individual_track'),
#  (161, 211, 1, 18, 'individual_track'),
#  (161, 321, 1, 12, 'individual_track'),
#  (162, 72, 1, 18, 'individual_track'),
#  (162, 83, 1, 24, 'individual_track'),
#  (162, 160, 1, 15, 'individual_track'),
#  (162, 182, 1, 12, 'individual_track'),
#  (162, 183, 1, 9, 'individual_track'),
#  (162, 203, 1, 17, 'individual_track'),
#  (162, 211, 1, 18, 'individual_track'),
#  (162, 214, 1, 11, 'individual_track'),
#  (162, 258, 1, 19, 'individual_track'),
#  (163, 61, 1, 11, 'individual_track'),
#  (163, 81, 1, 11, 'individual_track'),
#  (163, 94, 1, 11, 'individual_track'),
#  (163, 164, 1, 12, 'individual_track'),
#  (163, 182, 1, 12, 'individual_track'),
#  (163, 188, 1, 11, 'individual_track'),
#  (163, 207, 1, 11, 'individual_track'),
#  (163, 215, 1, 14, 'individual_track'),
#  (163, 245, 1, 12, 'individual_track'),
#  (164, 73, 1, 30, 'individual_track'),
#  (164, 120, 1, 17, 'individual_track'),
#  (164, 246, 1, 13, 'individual_track'),
#  (164, 260, 1, 1, 'album'),
#  (165, 7, 1, 12, 'individual_track'),
#  (165, 8, 1, 14, 'individual_track'),
#  (165, 89, 1, 13, 'individual_track'),
#  (165, 91, 1, 16, 'individual_track'),
#  (165, 141, 1, 57, 'individual_track'),
#  (165, 183, 1, 9, 'individual_track'),
#  (165, 184, 1, 16, 'individual_track'),
#  (165, 221, 1, 20, 'individual_track'),
#  (166, 7, 1, 12, 'individual_track'),
#  (166, 119, 1, 13, 'individual_track'),
#  (166, 140, 1, 16, 'individual_track'),
#  (166, 164, 1, 12, 'individual_track'),
#  (166, 214, 1, 11, 'individual_track'),
#  (166, 215, 1, 14, 'individual_track'),
#  (166, 239, 1, 10, 'individual_track'),
#  (166, 246, 1, 13, 'individual_track'),
#  (166, 257, 1, 12, 'individual_track'),
#  (166, 322, 1, 11, 'individual_track'),
#  (167, 39, 1, 21, 'individual_track'),
#  (167, 89, 1, 13, 'individual_track'),
#  (167, 123, 1, 12, 'individual_track'),
#  (167, 131, 1, 8, 'individual_track'),
#  (167, 134, 1, 10, 'individual_track'),
#  (167, 160, 1, 15, 'individual_track'),
#  (168, 7, 1, 12, 'individual_track'),
#  (168, 47, 1, 14, 'individual_track'),
#  (168, 149, 1, 16, 'individual_track'),
#  (168, 207, 1, 11, 'individual_track'),
#  (168, 267, 1, 1, 'album'),
#  (168, 322, 1, 11, 'individual_track'),
#  (169, 4, 1, 8, 'individual_track'),
#  (169, 83, 1, 24, 'individual_track'),
#  (169, 163, 1, 17, 'individual_track'),
#  (169, 180, 1, 15, 'individual_track'),
#  (169, 182, 1, 12, 'individual_track'),
#  (169, 188, 1, 11, 'individual_track'),
#  (169, 215, 1, 14, 'individual_track'),
#  (169, 225, 1, 16, 'individual_track'),
#  (169, 321, 1, 12, 'individual_track'),
#  (170, 17, 1, 10, 'individual_track'),
#  (170, 83, 1, 24, 'individual_track'),
#  (170, 118, 1, 11, 'individual_track'),
#  (170, 141, 1, 57, 'individual_track'),
#  (170, 185, 1, 17, 'individual_track'),
#  (170, 207, 2, 11, 'individual_track'),
#  (170, 215, 1, 14, 'individual_track'),
#  (170, 217, 1, 14, 'individual_track'),
#  (170, 269, 1, 10, 'individual_track'),
#  (171, 119, 13, 13, 'album'),
#  (172, 92, 1, 14, 'individual_track'),
#  (172, 132, 1, 9, 'individual_track'),
#  (172, 140, 1, 16, 'individual_track'),
#  (172, 188, 1, 11, 'individual_track'),
#  (172, 217, 1, 14, 'individual_track'),
#  (172, 224, 1, 22, 'individual_track'),
#  (172, 241, 1, 14, 'individual_track'),
#  (172, 242, 1, 12, 'individual_track'),
#  (173, 188, 11, 11, 'album'),
#  (174, 36, 1, 17, 'individual_track'),
#  (174, 37, 1, 20, 'individual_track'),
#  (174, 73, 1, 30, 'individual_track'),
#  (174, 163, 1, 17, 'individual_track'),
#  (174, 196, 1, 14, 'individual_track'),
#  (174, 218, 1, 15, 'individual_track'),
#  (174, 237, 1, 17, 'individual_track'),
#  (175, 145, 18, 18, 'album'),
#  (176, 73, 1, 30, 'individual_track'),
#  (176, 92, 1, 14, 'individual_track'),
#  (176, 186, 1, 11, 'individual_track'),
#  (176, 194, 1, 16, 'individual_track'),
#  (176, 214, 1, 11, 'individual_track'),
#  (176, 215, 1, 14, 'individual_track'),
#  (176, 260, 1, 1, 'album'),
#  (177, 83, 1, 24, 'individual_track'),
#  (177, 256, 1, 12, 'individual_track'),
#  (178, 87, 3, 3, 'album'),
#  (179, 6, 1, 13, 'individual_track'),
#  (179, 17, 1, 10, 'individual_track'),
#  (179, 72, 1, 18, 'individual_track'),
#  (179, 73, 1, 30, 'individual_track'),
#  (179, 133, 1, 9, 'individual_track'),
#  (179, 203, 1, 17, 'individual_track'),
#  (179, 211, 2, 18, 'individual_track'),
#  (179, 238, 1, 14, 'individual_track'),
#  (179, 246, 1, 13, 'individual_track'),
#  (180, 90, 1, 12, 'individual_track'),
#  (180, 146, 1, 18, 'individual_track'),
#  (180, 148, 1, 12, 'individual_track'),
#  (180, 152, 1, 8, 'individual_track'),
#  (180, 163, 2, 17, 'individual_track'),
#  (180, 183, 1, 9, 'individual_track'),
#  (180, 211, 1, 18, 'individual_track'),
#  (180, 227, 1, 19, 'individual_track'),
#  (180, 277, 1, 1, 'album'),
#  (181, 119, 1, 13, 'individual_track'),
#  (181, 121, 1, 10, 'individual_track'),
#  (181, 125, 1, 16, 'individual_track'),
#  (181, 126, 1, 15, 'individual_track'),
#  (181, 160, 1, 15, 'individual_track'),
#  (181, 163, 1, 17, 'individual_track'),
#  (181, 203, 1, 17, 'individual_track'),
#  (182, 10, 1, 14, 'individual_track'),
#  (182, 75, 1, 14, 'individual_track'),
#  (182, 121, 1, 10, 'individual_track'),
#  (182, 157, 1, 14, 'individual_track'),
#  (182, 206, 1, 12, 'individual_track'),
#  (182, 221, 1, 20, 'individual_track'),
#  (183, 83, 24, 24, 'album'),
#  (184, 278, 1, 1, 'album'),
#  (185, 73, 1, 30, 'individual_track'),
#  (185, 79, 1, 10, 'individual_track'),
#  (185, 137, 1, 5, 'individual_track'),
#  (185, 146, 1, 18, 'individual_track'),
#  (185, 152, 1, 8, 'individual_track'),
#  (185, 163, 1, 17, 'individual_track'),
#  (185, 207, 1, 11, 'individual_track'),
#  (185, 218, 1, 15, 'individual_track'),
#  (185, 244, 1, 11, 'individual_track'),
#  (186, 67, 1, 16, 'individual_track'),
#  (186, 120, 1, 17, 'individual_track'),
#  (186, 257, 1, 12, 'individual_track'),
#  (187, 83, 1, 24, 'individual_track'),
#  (187, 88, 1, 12, 'individual_track'),
#  (187, 119, 1, 13, 'individual_track'),
#  (187, 125, 1, 16, 'individual_track'),
#  (187, 182, 1, 12, 'individual_track'),
#  (187, 183, 1, 9, 'individual_track'),
#  (187, 203, 1, 17, 'individual_track'),
#  (188, 118, 11, 11, 'album'),
#  (189, 180, 1, 15, 'individual_track'),
#  (189, 212, 1, 12, 'individual_track'),
#  (189, 214, 1, 11, 'individual_track'),
#  (189, 302, 1, 1, 'album'),
#  (190, 67, 1, 16, 'individual_track'),
#  (190, 141, 1, 57, 'individual_track'),
#  (190, 207, 1, 11, 'individual_track'),
#  (190, 214, 1, 11, 'individual_track'),
#  (190, 260, 1, 1, 'album'),
#  (191, 5, 1, 15, 'individual_track'),
#  (191, 120, 2, 17, 'individual_track'),
#  (191, 216, 1, 12, 'individual_track'),
#  (192, 13, 1, 8, 'individual_track'),
#  (192, 17, 1, 10, 'individual_track'),
#  (192, 119, 1, 13, 'individual_track'),
#  (192, 125, 1, 16, 'individual_track'),
#  (192, 214, 3, 11, 'individual_track'),
#  (192, 321, 2, 12, 'individual_track'),
#  (193, 206, 1, 12, 'individual_track'),
#  (193, 207, 1, 11, 'individual_track'),
#  (194, 119, 1, 13, 'individual_track'),
#  (195, 7, 1, 12, 'individual_track'),
#  (195, 56, 1, 15, 'individual_track'),
#  ...]

# %% [markdown]
# ##### caculate price of a album, then calculate revenue for individual and revenue

# %%
# %%sql
# DROP VIEW IF EXISTS album_price;
# CREATE VIEW album_price AS
# SELECT
#     album_id,
#     sum(unit_price) price
# FROM
#     (
#     SELECT
#         DISTINCT tr.track_id,
#         tr.album_id,
#         il.unit_price
#     FROM track tr
#     INNER JOIN invoice_line il ON il.track_id=tr.track_id
#     )
# GROUP BY 1;
#
# SELECT
#     SUM(alp.price) as sum_album,
#     ((SELECT SUM(total) FROM invoice)- SUM(alp.price)) as sum_individual
# FROM invoice_album_track iat
# INNER JOIN album_price alp ON alp.album_id=iat.album_id
# WHERE album_individualtrack="album"
# GROUP BY album_individualtrack;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# Done.
# Done.
# [(1553.3100000000009, 3156.119999999993)]

# %% [markdown]
# ##### second way: found that unit price is the same at 0.99 USD per track so we can calculate as below:

# %%
# %%sql
# SELECT
#     album_individualtrack,
#     COUNT (album_individualtrack) as purchased_number,
#     SUM(number_tracks*0.99) as revenue
# FROM invoice_album_track
# GROUP BY album_individualtrack;
# Out:
#  * sqlite:///chinook-unmodified.db
# Done.
# [('album', 207, 1553.3100000000009),
#  ('individual_track', 2870, 3156.1199999998175)]

# %% [markdown]
# Based on this data, I would recommend against purchasing only select tracks from albums from record companies, since there is potential to lose one fifth of revenue.
